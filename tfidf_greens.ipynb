# %%
import numpy as np
import pandas as pd
import csv

import nltk
from nltk.corpus import stopwords
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

# read csv into a dataframe
df_idf = pd.read_csv("DataSources/small_name_review_green.csv")
 
# print schema
print(df_idf.dtypes)
print(df_idf.shape)
# Out:
# name       object
# text       object
# rating    float64
# dtype: object
# (84, 3)

# %%
df_idf
# Out:
#                                name  \
# 0                           ARTISAN
# 1                  THE LOBSTER TRAP
# 2          THE BREADFRUIT & RUM BAR
# 3                           SEVICHE
# 4                     SEAFOOD SHACK
# 5                        SAM'S CAFE
# 6                       RED LOBSTER
# 7             PARK PLACE RESTAURANT
# 8                       URBAN CRAVE
# 9          MONTEREY BAY FISH GROTTO
# 10                       MCDONALD'S
# 11             OFF THE HOOK FISHBAR
# 12                      JAMBA JUICE
# 13                    CASA FIGUEROA
# 14                     CANAL STREET
# 15               BUFFALO WILD WINGS
# 16                     BORDER GRILL
# 17                      BENTO SUSHI
# 18                LE GRAND COMPTOIR
# 19                     URBAN FARMER
# 20               HARMONY RESTAURANT
# 21                        BLACKBIRD
# 22                 PARTNERS KITCHEN
# 23          CAMILLE'S SIDEWALK CAFE
# 24                           STRADA
# 25                THE GREAT IMPASTA
# 26            THE GREENHOUSE TAVERN
# 27                    THE SUSHI BAR
# 28                    #1 FRIED RICE
# 29             #1 HAWAIIAN BARBECUE
# ..                              ...
# 54                     1000 GRAMMES
# 55  1001 NIGHTS HOOKAH & RESTAURANT
# 56                 100TH BOMB GROUP
# 57                             100℃
# 58                 101 ASIAN BUFFET
# 59                       101 BISTRO
# 60  101 BOTTLES OF BEER ON THE WALL
# 61         101 VAPOR AND CIGAR SHOP
# 62                    107 SKYLOUNGE
# 63                       11 SCALINI
# 64                       111 BISTRO
# 65              1130 THE RESTAURANT
# 66                     12 EAST CAFE
# 67                      12 O' LUNCH
# 68                        12 TABLES
# 69                  12 WEST BREWING
# 70                        120 DINER
# 71                      123 BULGOGI
# 72         12TH FAIRWAY BAR & GRILL
# 73                         131 MAIN
# 74              131 MAIN RESTAURANT
# 75                             1311
# 76                  1360 WEST GRILL
# 77             1410 WORLD BIER HAUS
# 78              1455 AMERICAN GRILL
# 79        15 NORTH ROADSIDE KITCHEN
# 80                   155 FAHRENHEIT
# 81                       157 LOUNGE
# 82  15° FAHRENHEIT ROLLED ICE CREAM
# 83    15°FAHRENHEIT ROLLED ICECREAM
#
#                                                  text  rating
# 0   [["Met with Sara today for a small coverup. Sh...     1.0
# 1   [["I have been coming here for years and have ...     1.0
# 2   [['Save your money and time.  It took over an ...     1.0
# 3   [['ATMOSPHERE: 5/5\nThe first word that came t...     1.0
# 4   [["Happy Hour Daily 3-6pm\n\nHappy hour specia...     1.0
# 5   [["Great ambience and absolutely adorable bar ...     1.0
# 6   [["We took our grandmother here for a going aw...     1.0
# 7   [["Just what you'd expect from a Greek diner. ...     1.0
# 8   [['As far as airport food goes  this is good. ...     1.0
# 9   [['We eat out 4-5 nights a week so are familia...     1.0
# 10  [["I have been going to McDonalds a lot lately...     1.0
# 11  [['As my friend and I had plans on seeing a co...     1.0
# 12  [["Food is good. Drinks are good. Don't expect...     1.0
# 13  [['This restaurant is a gem ! The food was del...     1.0
# 14  [["I really like Canal Street.  As tourists  w...     1.0
# 15  [["I am very upset with this location. I place...     1.0
# 16  [['Pick any meat on the planet and the chef wi...     1.0
# 17  [["This is pretty standard airport sushi. The ...     1.0
# 18  [["This was the second time I've been Le Grand...     1.0
# 19  [["This is for lunch only. I wish we'd had the...     1.0
# 20  [["Fairly new and already lots of people have ...     2.0
# 21  [['A nice hip lounge that is dark and mainly f...     2.0
# 22  [['Awesome vegetarian food. Live in the area a...     3.0
# 23  [['Went on a weekend and ordered a smoothie an...     3.0
# 24  [['I went to work in the Union before a windsu...     3.0
# 25  [["The Great Impasta is fantastic.  The menu c...     3.0
# 26  [['Very good food but pricey\n\nLow rating due...     3.0
# 27  [["Went there with my wife on a weeknight for ...     3.0
# 28  [['Really good food  big portions decent price...     NaN
# 29  [["Ordered fried mahimahi. Unfortunately made ...     NaN
# ..                                                ...     ...
# 54  [["L'endroit s'appelait Kilo mais a dû changer...     NaN
# 55  [['The meal was excellent and fresh serice was...     NaN
# 56  [['Friday after work I stop in for a good meal...     NaN
# 57  [['Extremely friendly service and amazing hot ...     NaN
# 58  [["Saw they had some very seriously bad health...     NaN
# 59  [['Must have eaten here a dozen times (used to...     NaN
# 60  [['Clean and neat and VERY friendly and helpfu...     NaN
# 61  [["This is my absolute favorite shop to come t...     NaN
# 62  [['The week of the July 4th holiday I had some...     NaN
# 63  [['Unbelievable food - great wine - spectacula...     NaN
# 64  [['Very good food. I got the Bahn Mi with the ...     NaN
# 65  [["Courtney the waiter was exceptional and the...     NaN
# 66  [['No wait. Good service. Great food. My new f...     NaN
# 67  [['This place was intriguing based on the desc...     NaN
# 68  [["This family-owned restaurant brings a cozy ...     NaN
# 69  [["Each time I visit I'm surprised by the vari...     NaN
# 70  [["I absolutely LOVE 120 Diner.  Friendly owne...     NaN
# 71  [["I loveeee 123 bulgogi and their owners are ...     NaN
# 72  [['People watching in Phoenix airport after ge...     NaN
# 73  [['Adam was amazing! The food was great. Doubl...     NaN
# 74  [['We love going to 131 Main  service is impec...     NaN
# 75  [["So I had got my two bars mixed up  but now ...     NaN
# 76  [["We love this place! This grill has amazing ...     NaN
# 77  [["Was brought here after a meeting with a col...     NaN
# 78  [["Thought we would try something new  glad we...     NaN
# 79  [['Made it over here for dinner this past week...     NaN
# 80  [["Came with Restomania's lobster festival dea...     NaN
# 81  [["The sushi here is pretty tasty. The prices ...     NaN
# 82  [["Fun to watch the ice cream masters roll the...     NaN
# 83  [['Noisy  but fun rolled ice cream shop.  One ...     NaN
#
# [84 rows x 3 columns]

# %%
green = df_idf.copy()
nongreen = df_idf.copy()

# %%
green = green[green['rating'].notnull()]
nongreen = nongreen[nongreen['rating'].isnull()]

# %%
green.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28 entries, 0 to 27
# Data columns (total 3 columns):
# name      28 non-null object
# text      28 non-null object
# rating    28 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 896.0+ bytes

# %%
nongreen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56 entries, 28 to 83
# Data columns (total 3 columns):
# name      56 non-null object
# text      56 non-null object
# rating    0 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 1.8+ KB

# %%
green = green.drop('rating', axis=1)
nongreen = nongreen.drop('rating', axis=1)

# %%
from nltk.stem import WordNetLemmatizer 
import re
def pre_process(text):
    # lowercase
    text=text.lower()
    #remove tags
    text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)
    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)
    
    return text

# %%
green['text'] = green['text'].apply(lambda x:pre_process(x))
nongreen['text'] = nongreen['text'].apply(lambda x:pre_process(x))

# %%
green.head()
# Out:
#                        name                                               text
# 0                   ARTISAN   met with sara today for a small coverup she w...
# 1          THE LOBSTER TRAP   i have been coming here for years and have to...
# 2  THE BREADFRUIT & RUM BAR   save your money and time it took over an hour...
# 3                   SEVICHE   atmosphere nthe first word that came to mind ...
# 4             SEAFOOD SHACK   happy hour daily pm n nhappy hour specials ar...

# %%
green['text'][2]
# Out:
# ' save your money and time it took over an hour just to get our lunch served and there was hardly anyone in the restaurant even after expressing to our waiter that we were in a rush n nordered off the basic taste of the island menu the ripped banana was not only ripped but petrified and tasteless not impressed especially for a restaurant near the asu downtown campus lots of other places that serve good quality food at a reasonable time the restaurant is quaint very pretty unfortunately the food is not as good as the place looks and the prices are not to put with the food either too pricey for a mediocre meal the pork chop is so tough you would expect a soft cut and such but they didn t cook it well t was like eating shoe leather the crab cakes are just bread barely any crab such a rip off they should invest on providing quality food having such a cute place the server was confused and scattered my whole party was unimpressed with the food would not recommend for food but only for drinks and the ambience heard about the breadfruit in an article in az vines wines it sounded so good we couldn t wait to try it it was outstanding the drinks the service the staff was amazing the food just incredible we can t wait to go again highly recommend it nwe just moved here from the east coast we are trying as many rest as we can nthis place is a must after years of visiting the rum bar for cocktails we finally got the chance to try the breadfruit for dinner i was so impressed by the excellent service my water glass was never empty i was given a fresh set of silverware between courses and all of my questions were promptly answered n ni got the red stripe curry prawns with rice and roasted vegetables the spice was perfect they are known for their jerk spice after all n nmy partner got the jerk pork and polenta and said that the ratio between pork and polenta seemed a little off but was otherwise very tasty i went to the breadfruit last night for dinner my mussels were absolutely delicious and so were the fresh rum cocktails they made however warning the menu is pricey and the portions are small i was still hungry when i left and i am a lb female it doesn t take much to make me full my suggestion go here for drinks apps go somewhere with adult sized portions for dinner breadfruit is honestly one of my favorite spots in phoenix my fiancé and i frequently come here whether it be to just enjoy a cocktail or have a delicious meal and romantic date night i highly recommend getting the scallops they are always perfectly cooked and i ve never been anywhere that serves a scallop dish that even comes close to what breadfruit offers service is also always incredible i came here a few weeks ago for my birthday the servers were nice the food was good the rum punch was excellent the portions were a nice size we had the coconut curried tofu smoked fish cabbage canape sorrel etc the rum menu is amazing they use local produce organic ingredients and i love the chic environment i must admit i wasn t too keen on the host up front he was a bit abrasive to my guests so you lost one star for that but overall we had a good time in the outside patio and i would return to try some other things took a friend here yesterday as she s new to town and hasn t yet experienced all downtown phoenix has to offer told her i thought breadfruit had some of the best food and drinks in downtown phoenix she said was curious about the place but was always reluctant because it had a low yelp rating so i came on here to see what was up n nyes they make the food the way the want without substitution cocktails are mixed the way they please too yes you cannot eat on their back patio boo hoo yes they only seat whole parties not all that uncommon n nget over it people you want great well balanced flavors and innovative rum cocktails i recommend the shorty make reservations you won t regret it delicious i ll be back for seconds and thirds and fourths n nin quintissential phoenix style breadfr ...

# %%
def remove_stopwords(mytext):
    #stop_words = set(stopwords.words('english')) 
    
    stop_words = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", 
                  "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", 
                  "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", 
                  "their", "theirs", "themselves", "what", "which", "who", "whom", "this", 
                  "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", 
                  "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", 
                  "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", 
                  "of", "at", "by", "for", "with", "about", "against", "between", "into", 
                  "through", "during", "before", "after", "above", "below", "to", "from", 
                  "up", "down", "in", "out", "on", "off", "over", "under", "again", "further",
                  "then", "once", "here", "there", "when", "where", "why", "how", "all", 
                  "any", "both", "each", "few", "more", "most", "other", "some", "such", 
                  "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", 
                  "s", "t", "can", "will", "just", "don", "should", "now", "also"]
    
    word_tokens = word_tokenize(mytext) 

    filtered_sentence = [w for w in word_tokens if not w in stop_words] 

    filtered_sentence = [] 

    for w in word_tokens: 
        if w not in stop_words: 
            filtered_sentence.append(w) 
    
    return filtered_sentence

# %%
import nltk
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

def lemmatize_text(text):
    return [' '.join(lemmatizer.lemmatize(w,'v') for w in w_tokenizer.tokenize(text))]

# %%
#clean will have no stopwords, mydfidf will
resultgreen = green.copy()
resultnongreen = nongreen.copy()

# %%
resultgreen['text'] = resultgreen['text'].apply(lambda x:remove_stopwords(x))
resultnongreen['text'] = resultnongreen['text'].apply(lambda x:remove_stopwords(x))

# %%
resultgreen['text'] = resultgreen['text'].str.join(' ')
resultnongreen['text'] = resultnongreen['text'].str.join(' ')

# %%
resultgreen['text_lemmatized'] = resultgreen.text.apply(lemmatize_text)
resultnongreen['text_lemmatized'] = resultnongreen.text.apply(lemmatize_text)

# %%
resultgreen.head()
# Out:
#                        name  \
# 0                   ARTISAN
# 1          THE LOBSTER TRAP
# 2  THE BREADFRUIT & RUM BAR
# 3                   SEVICHE
# 4             SEAFOOD SHACK
#
#                                                 text  \
# 0  met sara today small coverup great work really...
# 1  coming years say best spot lobster north great...
# 2  save money time took hour get lunch served har...
# 3  atmosphere nthe first word came mind walked pl...
# 4  happy hour daily pm n nhappy hour specials dri...
#
#                                      text_lemmatized
# 0  [meet sara today small coverup great work real...
# 1  [come years say best spot lobster north great ...
# 2  [save money time take hour get lunch serve har...
# 3  [atmosphere nthe first word come mind walk pla...
# 4  [happy hour daily pm n nhappy hour specials dr...

# %%
resultnongreen.head()
# Out:
#                     name                                               text  \
# 28         #1 FRIED RICE  really good food big portions decent price eno...
# 29  #1 HAWAIIAN BARBECUE  ordered fried mahimahi unfortunately made anot...
# 30                #1 PHO  fantastic pho vegetable pho vegetable broth ev...
# 31              #1 SUSHI  love place amazing cheap sushi thats fresh del...
# 32      #1BROTHERS PIZZA  good thing place price value good get pay pizz...
#
#                                       text_lemmatized
# 28  [really good food big portion decent price eno...
# 29  [order fry mahimahi unfortunately make another...
# 30  [fantastic pho vegetable pho vegetable broth e...
# 31  [love place amaze cheap sushi thats fresh deli...
# 32  [good thing place price value good get pay piz...

# %%
resultgreen['text_lemmatized'][2]
# Out:
# ['save money time take hour get lunch serve hardly anyone restaurant even express waiter rush n nordered basic taste island menu rip banana rip petrify tasteless impress especially restaurant near asu downtown campus lot place serve good quality food reasonable time restaurant quaint pretty unfortunately food good place look price put food either pricey mediocre meal pork chop tough would expect soft cut didn cook well like eat shoe leather crab cake bread barely crab rip invest provide quality food cute place server confuse scatter whole party unimpressed food would recommend food drink ambience hear breadfruit article az vines win sound good couldn wait try outstanding drink service staff amaze food incredible wait go highly recommend nwe move east coast try many rest nthis place must years visit rum bar cocktails finally get chance try breadfruit dinner impress excellent service water glass never empty give fresh set silverware course question promptly answer n ni get red stripe curry prawn rice roast vegetables spice perfect know jerk spice n nmy partner get jerk pork polenta say ratio pork polenta seem little otherwise tasty go breadfruit last night dinner mussels absolutely delicious fresh rum cocktails make however warn menu pricey portion small still hungry leave lb female doesn take much make full suggestion go drink apps go somewhere adult size portion dinner breadfruit honestly one favorite spot phoenix fiancé frequently come whether enjoy cocktail delicious meal romantic date night highly recommend get scallop always perfectly cook ve never anywhere serve scallop dish even come close breadfruit offer service always incredible come weeks ago birthday servers nice food good rum punch excellent portion nice size coconut curry tofu smoke fish cabbage canape sorrel etc rum menu amaze use local produce organic ingredients love chic environment must admit wasn keen host front bite abrasive guests lose one star overall good time outside patio would return try things take friend yesterday new town hasn yet experience downtown phoenix offer tell think breadfruit best food drink downtown phoenix say curious place always reluctant low yelp rat come see n nyes make food way want without substitution cocktails mix way please yes eat back patio boo hoo yes seat whole party uncommon n nget people want great well balance flavor innovative rum cocktails recommend shorty make reservations win regret delicious ll back second thirds fourths n nin quintissential phoenix style breadfruit house unassuming small space nondescript neighborhood close heart downtown space need little character decor qualify true phoenix hide gem status moment first week existence time tell n nstill sell first glance menu lot stuff ve never hear descriptions tempt taste bud decide zero brown chicken stew actually stew however want describe damn tasty starter friend split two dollar chicken curry patty d describe cross crust apple less apple turnover samosa chicken curry yum could see go back eat another one alone n na small complaint one often american restaurants addict overstuff obese customers concern portion size like favor smaller portion restaurant go brown chicken stew good leave want notch beware re new particular entree chicken contain bone n nthe service alright waitstaff strike bunch dudes oppose professional waiters waitress dude perfectly friendly n nanother great addition downtown scene suggest consider expand friday saturday night hours though hard place locate build shadow tree dont take rum bar neat little place mojitos best ve phoenix contain large sprigs fresh mint good rum ve try drink fine like deviate far beloved mojito love sit patio cooler months pretend m place phoenix place terrible disappointment tonight make portion smaller expensive staff inexperienced insensitive leave us hang night overall sad place become love place every time awesome food drink service great go little picky eater like like would throw fit eat something eat list ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
greenvectorizer = TfidfVectorizer(max_features=100, smooth_idf=True, )#tokenizer=tokens ,use_idf=True, smooth_idf=True, sublinear_tf=False)
nongreenvectorizer = TfidfVectorizer(max_features=100, smooth_idf=True, )#tokenizer=tokens ,use_idf=True, smooth_idf=True, sublinear_tf=False)

# %%
greenmatrix = greenvectorizer.fit_transform(resultgreen['text'])
nongreenmatrix = nongreenvectorizer.fit_transform(resultnongreen['text'])

# %%
print(greenvectorizer.get_feature_names())
# Out:
# ['always', 'another', 'around', 'asked', 'back', 'bad', 'bar', 'best', 'better', 'came', 'chicken', 'come', 'could', 'customer', 'day', 'didn', 'drink', 'drinks', 'drive', 'eat', 'even', 'ever', 'every', 'experience', 'fast', 'first', 'food', 'fresh', 'friendly', 'fries', 'get', 'give', 'go', 'going', 'good', 'got', 'great', 'know', 'last', 'like', 'little', 'lobster', 'location', 'long', 'love', 'made', 'make', 'manager', 'mcdonald', 'mcdonalds', 'meal', 'menu', 'minutes', 'much', 'never', 'ni', 'nice', 'night', 'nthe', 'one', 'order', 'ordered', 'people', 'place', 'pretty', 're', 'really', 'restaurant', 'right', 'said', 'sauce', 'say', 'server', 'service', 'shrimp', 'something', 'staff', 'still', 'sure', 'table', 'take', 'think', 'thru', 'time', 'times', 'told', 'took', 'try', 'two', 'us', 've', 'wait', 'want', 'way', 'well', 'went', 'wings', 'worst', 'would', 'wrong']

# %%
print(nongreenvectorizer.get_feature_names())
# Out:
# ['always', 'amazing', 'area', 'around', 'back', 'bar', 'beef', 'beer', 'best', 'better', 'bit', 'came', 'cheese', 'chicken', 'chocolate', 'come', 'could', 'definitely', 'delicious', 'dessert', 'didn', 'dinner', 'drink', 'drinks', 'eat', 'even', 'everything', 'experience', 'first', 'food', 'fresh', 'friendly', 'get', 'give', 'go', 'going', 'good', 'got', 'great', 'happy', 'hot', 'hour', 'know', 'like', 'little', 'love', 'lunch', 'made', 'main', 'make', 'meal', 'menu', 'much', 'never', 'ni', 'nice', 'night', 'nthe', 'one', 'order', 'ordered', 'people', 'pizza', 'place', 'pretty', 'price', 're', 'really', 'recommend', 'restaurant', 'rice', 'right', 'said', 'salad', 'sauce', 'say', 'see', 'server', 'service', 'side', 'small', 'staff', 'still', 'sure', 'table', 'take', 'think', 'time', 'top', 'try', 'two', 'us', 've', 'view', 'wait', 'want', 'way', 'well', 'went', 'would']

# %%
print(greenmatrix.shape)
# Out:
# (28, 100)

# %%
print(nongreenmatrix.shape)
# Out:
# (56, 100)
