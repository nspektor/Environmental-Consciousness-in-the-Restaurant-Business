# %%
import numpy as np
import pandas as pd
import csv

import nltk
from nltk.corpus import stopwords
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

# read csv into a dataframe
df_idf = pd.read_csv("BDSProject/DataSources/small_name_review_green.csv")
 
# print schema
print(df_idf.dtypes)
print(df_idf.shape)
# Out:
# name       object
# text       object
# rating    float64
# dtype: object
# (84, 3)

# %%
df_idf.head()
# Out:
#                        name  \
# 0                   ARTISAN
# 1          THE LOBSTER TRAP
# 2  THE BREADFRUIT & RUM BAR
# 3                   SEVICHE
# 4             SEAFOOD SHACK
#
#                                                 text  rating
# 0  [["Met with Sara today for a small coverup. Sh...     1.0
# 1  [["I have been coming here for years and have ...     1.0
# 2  [['Save your money and time.  It took over an ...     1.0
# 3  [['ATMOSPHERE: 5/5\nThe first word that came t...     1.0
# 4  [["Happy Hour Daily 3-6pm\n\nHappy hour specia...     1.0

# %%
mydfidf = df_idf.copy()
mydfidf = mydfidf.drop('rating', axis=1)

# %%
mydfidf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 2 columns):
# name    84 non-null object
# text    84 non-null object
# dtypes: object(2)
# memory usage: 1.4+ KB

# %%
from nltk.stem import WordNetLemmatizer 
import re
def pre_process(text):

    # lowercase
    text=text.lower()
    
    #remove tags
    text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)
    
    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)
    
    #splittext = text.split(' ')
    #lemmatizer = WordNetLemmatizer() 
    
    #lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in splittext])
    
    return text#lemmatized_output

# %%
mydfidf['text'] = mydfidf['text'].apply(lambda x:pre_process(x))

# %%
mydfidf.head()
# Out:
#                        name                                               text
# 0                   ARTISAN   met with sara today for a small coverup she w...
# 1          THE LOBSTER TRAP   i have been coming here for year and have to ...
# 2  THE BREADFRUIT & RUM BAR   save your money and time it took over an hour...
# 3                   SEVICHE   atmosphere nthe first word that came to mind ...
# 4             SEAFOOD SHACK   happy hour daily pm n nhappy hour special are...

# %%
mydfidf['text'][2]
# Out:
# ' save your money and time it took over an hour just to get our lunch served and there wa hardly anyone in the restaurant even after expressing to our waiter that we were in a rush n nordered off the basic taste of the island menu the ripped banana wa not only ripped but petrified and tasteless not impressed especially for a restaurant near the asu downtown campus lot of other place that serve good quality food at a reasonable time the restaurant is quaint very pretty unfortunately the food is not a good a the place look and the price are not to put with the food either too pricey for a mediocre meal the pork chop is so tough you would expect a soft cut and such but they didn t cook it well t wa like eating shoe leather the crab cake are just bread barely any crab such a rip off they should invest on providing quality food having such a cute place the server wa confused and scattered my whole party wa unimpressed with the food would not recommend for food but only for drink and the ambience heard about the breadfruit in an article in az vine wine it sounded so good we couldn t wait to try it it wa outstanding the drink the service the staff wa amazing the food just incredible we can t wait to go again highly recommend it nwe just moved here from the east coast we are trying a many rest a we can nthis place is a must after year of visiting the rum bar for cocktail we finally got the chance to try the breadfruit for dinner i wa so impressed by the excellent service my water glass wa never empty i wa given a fresh set of silverware between course and all of my question were promptly answered n ni got the red stripe curry prawn with rice and roasted vegetable the spice wa perfect they are known for their jerk spice after all n nmy partner got the jerk pork and polenta and said that the ratio between pork and polenta seemed a little off but wa otherwise very tasty i went to the breadfruit last night for dinner my mussel were absolutely delicious and so were the fresh rum cocktail they made however warning the menu is pricey and the portion are small i wa still hungry when i left and i am a lb female it doesn t take much to make me full my suggestion go here for drink apps go somewhere with adult sized portion for dinner breadfruit is honestly one of my favorite spot in phoenix my fiancé and i frequently come here whether it be to just enjoy a cocktail or have a delicious meal and romantic date night i highly recommend getting the scallop they are always perfectly cooked and i ve never been anywhere that serf a scallop dish that even come close to what breadfruit offer service is also always incredible i came here a few week ago for my birthday the server were nice the food wa good the rum punch wa excellent the portion were a nice size we had the coconut curried tofu smoked fish cabbage canape sorrel etc the rum menu is amazing they use local produce organic ingredient and i love the chic environment i must admit i wasn t too keen on the host up front he wa a bit abrasive to my guest so you lost one star for that but overall we had a good time in the outside patio and i would return to try some other thing took a friend here yesterday a she s new to town and hasn t yet experienced all downtown phoenix ha to offer told her i thought breadfruit had some of the best food and drink in downtown phoenix she said wa curious about the place but wa always reluctant because it had a low yelp rating so i came on here to see what wa up n nyes they make the food the way the want without substitution cocktail are mixed the way they please too yes you cannot eat on their back patio boo hoo yes they only seat whole party not all that uncommon n nget over it people you want great well balanced flavor and innovative rum cocktail i recommend the shorty make reservation you won t regret it delicious i ll be back for second and third and fourth n nin quintissential phoenix style breadfruit is housed in an unassuming small space in a nondescript neighbo ...

# %%
def remove_stopwords(mytext):
    #set(stopwords.words('english'))
    stop_words = set(stopwords.words('english')) 
    word_tokens = word_tokenize(mytext) 

    filtered_sentence = [w for w in word_tokens if not w in stop_words] 

    filtered_sentence = [] 

    for w in word_tokens: 
        if w not in stop_words: 
            filtered_sentence.append(w) 
    
    return filtered_sentence

# %%
def lemma(mytext):
    #splittext = mytext.split(' ')
    lemmatizer = WordNetLemmatizer() 
    
    lemmatized_output = [lemmatizer.lemmatize(w) for w in mytext]#splittext]
    #print(lemmatized_output)
    #text = lemmatizer.lemmatize(text)
    return lemmatized_output

# %%
#clean will have no stopwords, mydfidf will
clean = mydfidf.copy()

# %%
clean['text'] = clean['text'].apply(lambda x:remove_stopwords(x))

# %%
clean['text'] = clean['text'].apply(lambda x:lemma(x))

# %%
clean.head()
# Out:
#                        name                                               text
# 0                   ARTISAN  [met, sara, today, small, coverup, wa, great, ...
# 1          THE LOBSTER TRAP  [coming, year, say, best, spot, lobster, north...
# 2  THE BREADFRUIT & RUM BAR  [save, money, time, took, hour, get, lunch, se...
# 3                   SEVICHE  [atmosphere, nthe, first, word, came, mind, wa...
# 4             SEAFOOD SHACK  [happy, hour, daily, pm, n, nhappy, hour, spec...

# %%
clean['text'] = clean['text'].str.join(' ')

# %%
clean.head()
# Out:
#                        name                                               text
# 0                   ARTISAN  met sara today small coverup wa great work rea...
# 1          THE LOBSTER TRAP  coming year say best spot lobster north great ...
# 2  THE BREADFRUIT & RUM BAR  save money time took hour get lunch served wa ...
# 3                   SEVICHE  atmosphere nthe first word came mind walked pl...


# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_features=300, smooth_idf=True, )#tokenizer=tokens ,use_idf=True, smooth_idf=True, sublinear_tf=False)

# %%
X = vectorizer.fit_transform(clean['text'])

# %%
print(vectorizer.get_feature_names())
# Out:
# ['actually', 'almost', 'also', 'always', 'amazing', 'another', 'anything', 'appetizer', 'area', 'around', 'ask', 'asked', 'atmosphere', 'away', 'awesome', 'back', 'bad', 'bar', 'bartender', 'beer', 'best', 'better', 'big', 'biscuit', 'bit', 'breakfast', 'brought', 'brunch', 'buffalo', 'burger', 'business', 'busy', 'bww', 'called', 'came', 'car', 'care', 'check', 'cheese', 'chicken', 'chip', 'clean', 'close', 'coffee', 'cold', 'come', 'coming', 'cooked', 'could', 'counter', 'couple', 'course', 'crab', 'cream', 'cup', 'customer', 'day', 'decided', 'definitely', 'delicious', 'dessert', 'different', 'dining', 'dinner', 'disappointed', 'dish', 'done', 'drink', 'drive', 'eat', 'eating', 'egg', 'either', 'else', 'employee', 'enough', 'even', 'ever', 'every', 'everyone', 'everything', 'excellent', 'expect', 'experience', 'extra', 'family', 'far', 'fast', 'favorite', 'feel', 'finally', 'find', 'first', 'fish', 'flavor', 'food', 'free', 'fresh', 'fried', 'friend', 'friendly', 'front', 'fry', 'full', 'game', 'gave', 'get', 'getting', 'girl', 'give', 'go', 'going', 'good', 'got', 'great', 'guy', 'ha', 'half', 'happy', 'hard', 'home', 'horrible', 'hot', 'hour', 'however', 'husband', 'ice', 'inside', 'instead', 'item', 'job', 'juice', 'keep', 'kid', 'kind', 'know', 'lady', 'large', 'last', 'le', 'least', 'left', 'let', 'like', 'line', 'little', 'lobster', 'location', 'long', 'look', 'looked', 'looking', 'lot', 'love', 'lunch', 'made', 'make', 'manager', 'many', 'maybe', 'mcdonald', 'mcdonalds', 'meal', 'meat', 'menu', 'min', 'minute', 'money', 'morning', 'much', 'name', 'need', 'never', 'new', 'next', 'ni', 'nice', 'night', 'nothing', 'nthe', 'nwe', 'ok', 'old', 'one', 'open', 'option', 'order', 'ordered', 'ordering', 'pay', 'people', 'perfect', 'person', 'place', 'plate', 'pm', 'point', 'portion', 'pretty', 'price', 'probably', 'problem', 'put', 'quality', 'quick', 'quite', 'really', 'reason', 'recommend', 'red', 'restaurant', 'review', 'right', 'rude', 'said', 'salad', 'sandwich', 'sat', 'sauce', 'say', 'seafood', 'seated', 'second', 'see', 'served', 'server', 'service', 'shrimp', 'side', 'since', 'sit', 'slow', 'small', 'someone', 'something', 'special', 'spicy', 'spot', 'staff', 'star', 'steak', 'still', 'stop', 'store', 'super', 'sure', 'sweet', 'table', 'taco', 'take', 'taste', 'tasted', 'tasty', 'tell', 'terrible', 'thing', 'think', 'though', 'thought', 'three', 'thru', 'time', 'today', 'told', 'took', 'top', 'tried', 'try', 'two', 'use', 'used', 'usually', 'vega', 'view', 'visit', 'wa', 'wait', 'waited', 'waiter', 'waiting', 'waitress', 'walked', 'want', 'wanted', 'water', 'way', 'week', 'well', 'went', 'wild', 'window', 'wing', 'without', 'work', 'working', 'worst', 'worth', 'would', 'wrong', 'year']

# %%
print(X.shape)
# Out:
# (84, 300)

# %%
X
