# %%
import csv
import pandas as pd
import numpy as np

# %%
rdf = pd.read_csv('DataSources/review.csv', header = 0)

# %%
bdf = pd.read_csv('DataSources/yelp_usa_biz.csv', header = 0)

# %%
bdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77332 entries, 0 to 77331
# Data columns (total 12 columns):
# Unnamed: 0      77332 non-null int64
# business_id     77332 non-null object
# categories      77332 non-null object
# name            77332 non-null object
# review_count    77332 non-null int64
# stars           77332 non-null float64
# address         76480 non-null object
# city            77332 non-null object
# state           77332 non-null object
# postal_code     77123 non-null object
# latitude        77332 non-null float64
# longitude       77332 non-null float64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 7.1+ MB

# %%
rdf.head()
# Out:
#               business_id  cool                 date  funny  \
# 0  ujmEBvifdJM6h6RLv4wQIg     0  2013-05-07 04:34:36    1.0
# 1  NZnhc2sEQy3RmzKTZnqtwQ     0  2017-01-14 21:30:33    0.0
# 2  WTqjgwHlXbSFevF32_DJVw     0  2016-11-09 20:09:03    0.0
# 3  ikCg8xy5JIg_NGPx-MSIDA     0  2018-01-09 20:56:38    0.0
# 4  b1b1eb3uo-w561D0ZfCEiQ     0  2018-01-30 23:07:38    0.0
#
#                 review_id  stars  \
# 0  Q1sbwvVQXV2734tPgoKj4Q    1.0
# 1  GJXCdrto3ASJOqKeVWPi6Q    5.0
# 2  2TzJjDVDEuAW6MR5Vuc1ug    5.0
# 3  yi0R0Ugj_xUx_Nek0-_Qig    5.0
# 4  11a8sVPMUFtaC7_ABRkmtw    1.0
#
#                                                 text  useful  \
# 0  Total bill for this horrible service? Over $8G...     6.0
# 1  I *adore* Travis at the Hard Rock's new Kelly ...     0.0
# 2  I have to say that this office really has it t...     3.0
# 3  Went in for a lunch. Steak sandwich was delici...     0.0
# 4  Today was my second out of three sessions I ha...     7.0
#
# ...

# %%
myrdf = rdf[['business_id','text']]

# %%
bdf.head()
# Out:
#    Unnamed: 0             business_id  \
# 0           1  QXAEGFB4oINsVuTFxEYKFQ
# 1           2  gnKjwL_1w79qoiV3IC_xQQ
# 2          11  1Dfx3zM-rW4n-31KeC8sJg
# 3          12  5t3KVdMnFgAYmSl1wYLhmA
# 4          13  fweCYi8FmbJXHCqLnwuk8w
#
#                                           categories  \
# 0  SPECIALTY FOOD, RESTAURANTS, DIM SUM, IMPORTED...
# 1                  SUSHI BARS, RESTAURANTS, JAPANESE
# 2  RESTAURANTS, BREAKFAST & BRUNCH, MEXICAN, TACO...
# 3  BARS, NIGHTLIFE, PUBS, BARBERS, BEAUTY & SPAS,...
# 4         ITALIAN, RESTAURANTS, PIZZA, CHICKEN WINGS
#
#                           name  review_count  stars  \
# 0   EMERALD CHINESE RESTAURANT           128    2.5
# 1  MUSASHI JAPANESE RESTAURANT           170    4.0
# 2                    TACO BELL            18    3.0
# 3  THE KILTED BUFFALO LANGTREE             9    3.5
# 4                MARCO'S PIZZA            16    4.0
#
#                      address                city state postal_code   latitude  \
# ...

# %%
#myrdf['text'] = myrdf['text'].str.replace(',', ' ')

# %%
myrdf.head()

# %%
mergedf = bdf.merge(myrdf, left_on='business_id', right_on='business_id', how='inner', suffixes=['_biz', '_rev'])

# %%
mergedf.head()
# Out:
#    Unnamed: 0             business_id  \
# 0           1  QXAEGFB4oINsVuTFxEYKFQ
# 1           1  QXAEGFB4oINsVuTFxEYKFQ
# 2           1  QXAEGFB4oINsVuTFxEYKFQ
# 3           1  QXAEGFB4oINsVuTFxEYKFQ
# 4           1  QXAEGFB4oINsVuTFxEYKFQ
#
#                                           categories  \
# 0  SPECIALTY FOOD, RESTAURANTS, DIM SUM, IMPORTED...
# 1  SPECIALTY FOOD, RESTAURANTS, DIM SUM, IMPORTED...
# 2  SPECIALTY FOOD, RESTAURANTS, DIM SUM, IMPORTED...
# 3  SPECIALTY FOOD, RESTAURANTS, DIM SUM, IMPORTED...
# 4  SPECIALTY FOOD, RESTAURANTS, DIM SUM, IMPORTED...
#
#                          name  review_count  stars               address  \
# 0  EMERALD CHINESE RESTAURANT           128    2.5  30 EGLINTON AVENUE W
# 1  EMERALD CHINESE RESTAURANT           128    2.5  30 EGLINTON AVENUE W
# 2  EMERALD CHINESE RESTAURANT           128    2.5  30 EGLINTON AVENUE W
# 3  EMERALD CHINESE RESTAURANT           128    2.5  30 EGLINTON AVENUE W
# ...

# %%
mergedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4686091 entries, 0 to 4686090
# Data columns (total 13 columns):
# Unnamed: 0      int64
# business_id     object
# categories      object
# name            object
# review_count    int64
# stars           float64
# address         object
# city            object
# state           object
# postal_code     object
# latitude        float64
# longitude       float64
# text            object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 500.5+ MB

# %%
mergedf.to_csv('biz_rev.csv')

# %%
nocommas = mergedf

# %%
nocommas['categories'] = nocommas['categories'].str.replace(',', ' ')

# %%
nocommas['text'] = nocommas['text'].str.replace(',', ' ')

# %%
nocommas.to_csv('biz_rev_nocommas.csv')

# %%
nocommas.head()
# Out:
#    Unnamed: 0             business_id  \
# 0           1  QXAEGFB4oINsVuTFxEYKFQ
# 1           1  QXAEGFB4oINsVuTFxEYKFQ
# 2           1  QXAEGFB4oINsVuTFxEYKFQ
# 3           1  QXAEGFB4oINsVuTFxEYKFQ
# 4           1  QXAEGFB4oINsVuTFxEYKFQ
#
#                                           categories  \
# 0  SPECIALTY FOOD  RESTAURANTS  DIM SUM  IMPORTED...
# 1  SPECIALTY FOOD  RESTAURANTS  DIM SUM  IMPORTED...
# 2  SPECIALTY FOOD  RESTAURANTS  DIM SUM  IMPORTED...
# 3  SPECIALTY FOOD  RESTAURANTS  DIM SUM  IMPORTED...
# 4  SPECIALTY FOOD  RESTAURANTS  DIM SUM  IMPORTED...
#
#                          name  review_count  stars               address  \
# 0  EMERALD CHINESE RESTAURANT           128    2.5  30 EGLINTON AVENUE W
# 1  EMERALD CHINESE RESTAURANT           128    2.5  30 EGLINTON AVENUE W
# 2  EMERALD CHINESE RESTAURANT           128    2.5  30 EGLINTON AVENUE W
# 3  EMERALD CHINESE RESTAURANT           128    2.5  30 EGLINTON AVENUE W
# ...
